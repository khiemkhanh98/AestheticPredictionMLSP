# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
# %cd /gdrive/MyDrive/SRP/Code/Baseline
# Out:
# /gdrive/MyDrive/SRP/Code/Baseline

# %%
# !pip install pretrainedmodels
# !pip install colab_ssh --upgrade

# %%
from colab_ssh import launch_ssh_cloudflared, init_git_cloudflared
launch_ssh_cloudflared(password="khiem")
# Out:
# <style>
# *{
# 	outline:none;
# }
# code{
# 	display:inline-block;
# 	padding:5px 10px;
# 	background: #444;
# 	border-radius: 4px;
# 	white-space: pre-wrap;
# 	position:relative;
# 	color:white;
# }
# .copy-code-button{
# 	float:right;
# 	background:#333;
# 	color:white;
# 	border: none;
# 	margin: 0 0 0 10px;
# 	cursor: pointer;
# }
# p, li{
# 	max-width:700px;
# }
# .choices{
# 	display:flex;
# 	flex: 1 0 auto;
# }
# .choice-section{
# 	border:solid 1px #555;
# 	border-radius: 4px;
# 	min-width:300px;
# 	margin: 10px 15px 0 0;
# 	padding: 0 15px 15px 15px ;
# }
# .button{
# 	padding: 10px 15px;
# 	background:#333;
# 	border-radius: 4px;
# 	border:solid 1px #555;
# 	color:white;
# 	font-weight:bold;
# 	cursor:pointer;
# }
# .pill{
# 	padding:2px 4px;
# 	border-radius: 100px;
# 	background-color:#e65858;
# 	font-size:12px;
# 	font-weight:bold;
# 	margin: 0 15px;
# 	color:white;
# }
# </style>
# <details class="choice-section">
# 	<summary style="cursor:pointer">
# ...

# %%
import pretrainedmodels
# %env TORCH_HOME=/gdrive/MyDrive/SRP/Code/Baseline/StudentResearchProject2021/pretrained_model
# Out:
# env: TORCH_HOME=/gdrive/MyDrive/SRP/Code/Baseline/StudentResearchProject2021/pretrained_model

# %%
model_name = 'inceptionresnet' # could be fbresnet152 or inceptionresnetv2
model = pretrainedmodels.__dict__[model_name](num_classes=1000, pretrained='imagenet')
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-5c106cde.pth" to /gdrive/MyDrive/SRP/Code/Baseline/StudentResearchProject2021/pretrained_model/hub/checkpoints/resnet18-5c106cde.pth
# ...

# %%
import numpy as np

a = np.zeros((1,3,256,256))
a = torch.autograd.Variable(a, requires_grad=False)
output_logits = model(a)
# Out:
# {'imagenet': {'input_range': [0, 1],
#   'input_size': [3, 224, 224],
#   'input_space': 'RGB',
#   'mean': [0.485, 0.456, 0.406],
#   'num_classes': 1000,
#   'std': [0.229, 0.224, 0.225],
#   'url': 'https://download.pytorch.org/models/resnet18-5c106cde.pth'}}
