# %%
# %load_ext autoreload

import numpy as np
import os
import torch
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %autoreload

from model.base_model import get_model,get_MLSP
from dataloader import *
from model.head import Head

batch_size = 10
lr = 1e-3
epochs = 10
base_model_type = 'inceptionv3'
feature_type = 'narrow'
head_type = 'single_3FC'
if head_type == 'multi_3FC':
    concat_features = False
else:
    concat_features = True

base_model,channel_size = get_model(model = base_model_type)
base_model(img)   
fea  = get_MLSP(feature_type, concat_features)

model = Head(head_type,channel_size)
out = model(fea)

# %%
fmodel = finetune_model(base_model,head,feature_type)
fmodel(fea)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-115-f7f02290f776> in <module>()
# ----> 1 fmodel = finetune_model(base_model,head,feature_type)
#       2 fmodel(fea)
#
# NameError: name 'finetune_model' is not defined
